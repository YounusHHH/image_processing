# %%
#code 1

import cv2

import numpy as np
from matplotlib import pyplot as plt

image = cv2.imread('image.png')

kernel1 = np.ones((5, 5), np.float32)/30



img = cv2.filter2D(src=image, ddepth=-1, kernel=kernel1)

res = np.hstack((image,img))
plt.imshow(res)
plt.show()

# %%
image = cv2.imread("image.png")
kernel1 = np.ones((5,5),np.float64)/30
img = cv2.filter2D(src=image, ddepth=-1, kernel=kernel1)
res = np.hstack((image,img))
plt.imshow(res)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17380\2005672230.py in <module>
# ----> 1 image = cv2.imread("image.png")
#       2 kernel1 = np.ones((5,5),np.float64)/30
#       3 img = cv2.filter2D(src=image, ddepth=-1, kernel=kernel1)
#       4 res = np.hstack((image,img))
#       5 plt.imshow(res)
#
# NameError: name 'cv2' is not defined

# %%
#code 2
path = r'image.png'
img = cv2.imread(path)
im1 = cv2.blur(img,(5,5))
im2 = cv2.boxFilter(img, -1,(2,2), normalize = True)
res = np.hstack((im1,im2))

plt.imshow(res)
plt.show()

# %%
#code 3
import cv2

import numpy as np
from matplotlib import pyplot as plt

image = cv2.imread("brain.jpg")
median = cv2.medianBlur(image,5)
compare = np.concatenate((image,median), axis=1)
plt.imshow(compare)
plt.show()

# %%
import sys
import cv2 as cv
import numpy as np
import cv2
from matplotlib import pyplot as plt
ddepth = cv.CV_16S
kernel_size = 3
image = cv2.imread("moon.jpg")
src = cv.GaussianBlur (image, (3, 3), 0)
src_gray = cv.cvtColor(src, cv.COLOR_BGR2GRAY)
dst = cv.Laplacian(src_gray, ddepth, ksize=kernel_size)
abs_dst = cv.convertScaleAbs(dst)
plt.imshow(image)
plt.show()
plt.imshow(abs_dst)
plt.show()
