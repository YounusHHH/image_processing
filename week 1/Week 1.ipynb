# %%
import numpy as np
array =np.zeros( (3,2) )
print(array)
# Out:
# [[0. 0.]
#  [0. 0.]
#  [0. 0.]]

# %%
array =np.ones( (1,5) )
print(array)
# Out:
# [[1. 1. 1. 1. 1.]]

# %%
n = int(input("Kac Adet Sayi Girilecek: "))
a = []
for i in range(0,n):
    elem = int(input("Sayiyi Girin: "))
    a.append(elem)
avg = sum(a) / n
print("Girilen Sayilarin Ortalamasi: ", round(avg,2))
# Out:
# Kac Adet Sayi Girilecek: 2
# Sayiyi Girin: 3
# Sayiyi Girin: 5
# Girilen Sayilarin Ortalamasi:  4.0
